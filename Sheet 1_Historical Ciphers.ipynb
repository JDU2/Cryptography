# %% [markdown]
# **Exercises on**
#
# **Historical Ciphers**

# %% [markdown]
# **Exercise 1 (The Caesar Cipher)**
#
# Implement the Caesar cipher in Sage for the upper-case Latin alphabet A–Z, where the key consists of
# an arbitrary shift. The skeletons of your encryp-tion and decryption functions should look like this:
#
# def caesar_encrypt(cleartext, key):
#
#     ...
#     return ciphertext
#
# def caesar_decrypt(ciphertext, key):
#
#     ...
#     return cleartext

# %%
def caesar_encrypt(cleartext, key):
    ciphertext = "".join([chr((ord(c)+65+key)%26+65) for c in cleartext])
    return ciphertext

# %%
caesar_encrypt("JULIAN", 8)
# Out:
# 'RCTQIV'

# %%
def caesar_decrypt(ciphertext, key):
    cleartext = caesar_encrypt(ciphertext, (-1)*key)
    return cleartext

# %%
caesar_decrypt('RCTQIV',8)
# Out:
# 'JULIAN'

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
def atbash(cleartext):
    E=lambda x: -(x+1)%26
    ciphertext="".join([chr(E(ord(c)-65)+65) for c in cleartext])
    return ciphertext

# %%
atbash("JULIAN")
# Out:
# 'QFORZM'

# %%
atbash('QFORZM')
# Out:
# 'JULIAN'

# %%
def atbash_new(cleartext, key):
    alph="ABCDEFGHIJKLMNOPQRSTUVWXYZ"
    E=lambda x: -(x+1)%26
    ciphertext="".join([key[E(alph.find(c))] for c in cleartext])
    return ciphertext

# %%
atbash_new("JULIAN","ABCDEFGHIJKLMNOPQRSTUVWXYZ")
# Out:
# 'QFORZM'
